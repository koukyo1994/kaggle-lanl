# %% [markdown]
# ## Libraries

# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

from pathlib import Path

plt.style.use("ggplot")
pd.options.display.max_colwidth = 500

# %% [markdown]
# ## Data Loading

# %%
input_dir = Path("../../input/")
test_dir = input_dir / "test"

train = pd.read_csv(input_dir / "train/train.csv", nrows=1e7)
test_path = list(test_dir.glob("*.csv"))

# %%
test = pd.read_csv(test_path[8])
test.plot(subplots=True, sharey=False, figsize=(10, 5));

# %%
train.head()
# Out:
#    acoustic_data  time_to_failure
# 0             12           1.4691
# 1              6           1.4691
# 2              8           1.4691
# 3              5           1.4691
# 4              8           1.4691

# %%
train.time_to_failure.argmin()
# Out:
# /Users/hidehisa/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: 'argmin' is deprecated, use 'idxmin' instead. The behavior of 'argmin'
# will be corrected to return the positional minimum in the future.
# Use 'series.values.argmin' to get the position of the minimum now.
#   """Entry point for launching an IPython kernel.
# 5656573

# %%
tra

# %%
train.plot(subplots=True, sharey=False);

# %%
1.4691 -

# %%
train.time_to_failure.argmin()
# Out:
# /Users/hidehisa/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: 'argmin' is deprecated, use 'idxmin' instead. The behavior of 'argmin'
# will be corrected to return the positional minimum in the future.
# Use 'series.values.argmin' to get the position of the minimum now.
#   """Entry point for launching an IPython kernel.
# 5656573

# %%
train.loc[5656500:5656600].plot(subplots=True, sharey=False, figsize=(10, 5));

# %%
train.head()
# Out:
#    acoustic_data  time_to_failure
# 0             12           1.4691
# 1              6           1.4691
# 2              8           1.4691
# 3              5           1.4691
# 4              8           1.4691
